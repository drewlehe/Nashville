# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
# %matplotlib inline
sns.set(style='darkgrid')

# %%
df= pd.read_csv('sales.csv')

# %%
df['Sale Date']=pd.to_datetime(df['Sale Date'], errors = 'coerce')
df['Month'] = df['Sale Date'].dt.month
df.tail()
# Out:
#               Parcel ID           Land Use  Property Address Suite/ Condo   #  \
# 72494  093 13 0C 057.00  RESIDENTIAL CONDO  600  12TH  AVE S              507
# 72495  093 13 0C 118.00  RESIDENTIAL CONDO  600  12TH  AVE S              629
# 72496  093 13 0C 310.00  RESIDENTIAL CONDO  600  12TH  AVE S             1607
# 72497  093 13 0C 329.00  RESIDENTIAL CONDO  600  12TH  AVE S             1709
# 72498  093 13 0D 110.00  RESIDENTIAL CONDO  700  12TH  AVE S             1112
#
#       Property City  Sale Date  Sale Price   Legal Reference Sold As Vacant  \
# 72494     NASHVILLE 2019-04-30      320000  20190501-0040543             No
# 72495     NASHVILLE 2019-04-16      449000  20190422-0036292             No
# 72496     NASHVILLE 2019-04-11      565000  20190416-0034978             No
# 72497     NASHVILLE 2019-04-10      575000  20190412-0033568             No
# 72498     NASHVILLE 2019-04-02      535000  20190403-0030428             No
#
#       Multiple Parcels Involved in Sale  Month
# 72494                                No      4
# 72495                                No      4
# 72496                                No      4
# 72497                                No      4
# 72498                                No      4

# %%
df['Property City'].unique()
# Out:
# array(['NASHVILLE', 'ANTIOCH', 'BRENTWOOD', 'NOLENSVILLE', 'WHITES CREEK',
#        'GOODLETTSVILLE', 'MADISON', 'OLD HICKORY', 'HERMITAGE',
#        'MOUNT JULIET', nan, 'JOELTON', 'UNKNOWN'], dtype=object)

# %%
city_count  = df['Property City'].value_counts()
city_count = city_count[:10,]
plt.figure(figsize=(10,5))
sns.barplot(city_count.index, city_count.values, alpha=0.8)
plt.xlabel('city', fontsize=12)
plt.show()
print(df['Property City'].value_counts())

#Note: I want to compare how development is distributed across cities for each year.
# Out:
# NASHVILLE         50380
# ANTIOCH            8702
# HERMITAGE          3978
# MADISON            3291
# OLD HICKORY        1944
# BRENTWOOD          1943
# GOODLETTSVILLE     1005
# NOLENSVILLE         850
# MOUNT JULIET        161
# WHITES CREEK        140
# JOELTON              11
# UNKNOWN               1
# Name: Property City, dtype: int64

# %%
df['Land Use'].value_counts().plot.bar()
print(df['Land Use'].value_counts())
# Out:
# SINGLE FAMILY                                 42820
# RESIDENTIAL CONDO                             20179
# VACANT RESIDENTIAL LAND                        5835
# DUPLEX                                         1624
# ZERO LOT LINE                                  1567
# RESIDENTIAL COMBO/MISC                           99
# TRIPLEX                                          87
# QUADPLEX                                         44
# CHURCH                                           42
# CONDOMINIUM OFC  OR OTHER COM CONDO              38
# SPLIT CLASS                                      31
# MOBILE HOME                                      26
# DORMITORY/BOARDING HOUSE                         21
# GREENBELT                                        13
# FOREST                                           11
# GREENBELT/RES\r\r\r\nGRRENBELT/RES               10
# PARSONAGE                                         5
# DAY CARE CENTER                                   5
# VACANT RESIDENTIAL                                4
# SMALL SERVICE SHOP                                4
# VACANT COMMERCIAL LAND                            3
# NON-PROFIT CHARITABLE SERVICE                     3
# VACANT RESIENTIAL LAND                            3
# METRO OTHER THAN OFC, SCHOOL,HOSP, OR PARK        2
# EXEMPT VACANT LAND                                2
# CLUB/UNION HALL/LODGE                             2
# OFFICE BLDG (ONE OR TWO STORIES)                  2
# TERMINAL/DISTRIBUTION WAREHOUSE                   2
# TRANSMITTING TOWERS                               2
# APARTMENT: LOW RISE (BUILT SINCE 1960)            2
# PARKING LOT                                       2
# VACANT RURAL LAND                                 1
# VACANT ZONED MULTI FAMILY                         1
# SCHOOL OR COLLEGE                                 1
# MORTUARY/CEMETERY                                 1
# NIGHTCLUB/LOUNGE                                  1
# SMALL WAREHOUSE                                   1
# GREENHOUSE/NURSERY                                1
# RESTURANT/CAFETERIA                               1
# CONVENIENCE MARKET WITHOUT GAS                    1
# Name: Land Use, dtype: int64

# %%
sns.violinplot(df['Sale Price'])

# %%
#sns.lineplot(x='Month',y=df[df['Land Use']=='RESIDENTIAL CONDO'],data=df)
byDate=df.set_index('Sale Date')
y = byDate['Sale Price'].resample('M').mean()
x= byDate['Sale Price'].resample('M').count()

# %%
y.plot()

# %%
x.plot()

# %%
from pandas import Series
plt.figure(figsize=(10,10))
Series(df['Sale Price']).plot()

# %% [markdown]
# ### Links for reference:
#
# https://machinelearningmastery.com/time-series-data-visualization-with-python/
#
# https://www.dataquest.io/blog/tutorial-time-series-analysis-with-pandas/
#
# https://stackoverflow.com/questions/26507404/time-series-boxplot-in-pandas
