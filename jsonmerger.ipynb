# %% [markdown]
# # JSON Merger

# %% [markdown]
# ## Links for Reference:
#
# https://www.dataquest.io/blog/python-json-tutorial/
#
# https://realpython.com/python-json/
#
# https://pythonspot.com/json-encoding-and-decoding-with-python/

# %%
import json
import pandas as pd

# %%
names = ['parcel{}.json'.format(i) for i in range(10000)]

# %%
result = []
for lot in range(1,1000):
    infile = 'Parcels/parcel{}'.format(lot)
    with open(infile, 'r') as infile:
        try:
            result.append(json.load(infile))
        except ValueError:
            continue

# %%
len(result)
# Out:
# 999

# %%
df = pd.DataFrame(result)

# %%
df.head(10)
# Out:
#   Assessment Classification* Assessment Improvement Assessment Land  \
# 0                     AG/RES                     $0          $2,655
# 1                     AG/RES                     $0          $4,081
# 2                        EXE                     $0              $0
# 3                        EXE                     $0              $0
# 4                        EXE                     $0              $0
# 5                      RURAL                 $6,950          $6,250
# 6                      RURAL                $22,175         $11,675
# 7                      RURAL                $27,425         $10,025
# 8                      RURAL                     $0          $4,950
# 9                      RURAL                     $0              $0
#
#   Assessment Total Assessment Year Baths Beds Building Condition  \
# 0           $2,655            2019
# 1           $4,081            2019
# 2               $0            2019
# 3               $0            2019     2    3               Poor
# 4               $0            2019
# 5          $13,200            2019
# 6          $33,850            2019     1    3               Fair
# 7          $37,450            2019     2    4            Average
# 8           $4,950            2019
# 9               $0            2019     2    3            Average
#
#   Building Grade Building Type ...  Neighborhood Number of Living Units  \
# 0                              ...          6801
# 1                              ...          6801
# 2                              ...          6802
# 3              E    SINGLE FAM ...          6802                      1
# 4                              ...          6802
# 5                              ...          6802
# 6              D    SINGLE FAM ...          6802                      1
# 7              C    SINGLE FAM ...          6802                      1
# 8                              ...          6802
# 9              C    SINGLE FAM ...          6802                      1
#
#   Roof Cover Rooms Square Footage Story Height Tax District  \
# 0                               0                       GSD
# 1                               0                       GSD
# 2                               0                       GSD
# 3      METAL     6          1,224      ONE STY           RT
# 4                               0                       GSD
# 5                               0                        RT
# 6    ASPHALT     7          1,920      ONE STY           RT
# 7    ASPHALT     7          1,464      ONE STY           RT
# 8                               0                        RT
# 9    ASPHALT     6          1,787      ONE STY          GSD
#
#   Total Appraisal Value Year Built Zone
# 0               $10,621               5
# 1               $16,323               5
# 2                    $0               5
# 3               $47,100       1932    5
# 4               $27,400               5
# 5               $52,800               5
# 6              $135,400       1964    5
# 7              $149,800       1962    5
# 8               $19,800               5
# 9                    $0       1960    5
#
# [10 rows x 35 columns]

# %%
df['Map & Parcel'].head()
# Out:
# 0        001 00 0 001.00
# 1        001 00 0 002.00
# 2        002 00 0 001.00
# 3    002 00 0 001.00 001
# 4    002 00 0 001.00 002
# Name: Map & Parcel, dtype: object

# %%
xdf = pd.read_csv('sales2016.csv')

xdf.head()
# Out:
#    Unnamed: 0         Parcel ID                 Land Use  \
# 0           0  105 03 0E 002.00        RESIDENTIAL CONDO
# 1           1   105 07 0 126.00  VACANT RESIDENTIAL LAND
# 2           2   105 07 0 136.00            SINGLE FAMILY
# 3           3   105 07 0 137.00  VACANT RESIDENTIAL LAND
# 4           4   105 07 0 156.00                   DUPLEX
#
#             Property Address Suite/ Condo   # Property City   Sale Date  \
# 0          1064 B  2ND AVE S              NaN     NASHVILLE  2016-01-08
# 1          1305 C  PILLOW ST              NaN     NASHVILLE  2016-01-04
# 2            1322  PILLOW ST              NaN     NASHVILLE  2016-01-29
# 3            1318  PILLOW ST              NaN     NASHVILLE  2016-01-29
# 4  1317  LITTLE HAMILTON AVE              NaN     NASHVILLE  2016-01-29
#
#    Sale Price   Legal Reference Sold As Vacant  \
# 0      218500  20160111-0002880             No
# 1      140000  20160106-0001041            Yes
# 2     1250000  20160202-0009909             No
# 3     1250000  20160202-0009909             No
# 4      205500  20160203-0010634             No
#
#   Multiple Parcels Involved in Sale
# 0                                No
# 1                                No
# 2                               Yes
# 3                               Yes
# 4                                No

# %%
jdf = df.merge(xdf, right_on='Parcel ID', left_on='Map & Parcel')

jdf.head(10)
# Out:
#   Assessment Classification* Assessment Improvement Assessment Land  \
# 0                        RES                $86,825         $20,000
# 1                        RES                $46,650         $20,000
# 2                        RES                $19,050         $20,800
# 3                        RES                $49,450         $16,250
# 4                        RES                $36,950         $16,250
# 5                        RES                $36,350         $16,250
# 6                        RES                $85,275         $21,475
#
#   Assessment Total Assessment Year Baths Beds Building Condition  \
# 0         $106,825            2019     3    4            Average
# 1          $66,650            2019     3    3            Average
# 2          $39,850            2019     1    3            Average
# 3          $65,700            2019     2    3            Average
# 4          $53,200            2019     2    4            Average
# 5          $52,600            2019     2    3            Average
# 6         $106,750            2019     4    5            Average
#
#   Building Grade Building Type                ...                 \
# 0              C    SINGLE FAM                ...
# 1              C    SINGLE FAM                ...
# 2              C    SINGLE FAM                ...
# 3              C    SINGLE FAM                ...
# 4              C    SINGLE FAM                ...
# 5              C    SINGLE FAM                ...
# 6              C     R1 DUPLEX                ...
#
#          Parcel ID       Land Use    Property Address Suite/ Condo   #  \
# 0  007 00 0 138.00  SINGLE FAMILY  1864 FOX CHASE  DR              NaN
# 1  007 00 0 143.00  SINGLE FAMILY  1853  FOX CHASE DR              NaN
# 2  007 10 0 009.00  SINGLE FAMILY     1972 TINNIN  RD              NaN
# 3  007 14 0 024.00  SINGLE FAMILY  1917 GRACELAND  DR              NaN
# 4  007 15 0 008.00  SINGLE FAMILY      1976 SADIE  LN              NaN
# 5  007 15 0 030.00  SINGLE FAMILY  2005 GRACELAND  DR              NaN
# 6  007 15 0 048.00  SINGLE FAMILY  2034  GRACELAND DR              NaN
#
#     Property City   Sale Date Sale Price   Legal Reference Sold As Vacant  \
# 0  GOODLETTSVILLE  2016-09-26     435000  20160927-0101718             No
# 1  GOODLETTSVILLE  2016-01-29     255000  20160129-0008913             No
# 2  GOODLETTSVILLE  2016-12-19     155000  20161220-0133510             No
# 3  GOODLETTSVILLE  2016-09-27     262000  20161005-0105441             No
# 4  GOODLETTSVILLE  2016-07-15     211500  20160720-0074793             No
# 5  GOODLETTSVILLE  2016-12-12     218500  20161214-0131015             No
# 6  GOODLETTSVILLE  2016-04-14     379900  20160418-0036715             No
#
#   Multiple Parcels Involved in Sale
# 0                                No
# 1                                No
# 2                                No
# 3                                No
# 4                                No
# 5                                No
# 6                                No
#
# [7 rows x 46 columns]

# %%
jdf.dtypes
# Out:
# Assessment Classification*           object
# Assessment Improvement               object
# Assessment Land                      object
# Assessment Total                     object
# Assessment Year                      object
# Baths                                object
# Beds                                 object
# Building Condition                   object
# Building Grade                       object
# Building Type                        object
# Current Owner                        object
# Deed Reference                       object
# Exterior Wall                        object
# Fixtures                             object
# Foundation Type                      object
# Frame Type                           object
# Half Bath                            object
# Improvement Value                    object
# Land Area                            object
# Land Value                           object
# Location                             object
# Mailing Address                      object
# Map & Parcel                         object
# Most Recent Sale Date                object
# Most Recent Sale Price               object
# Neighborhood                         object
# Number of Living Units               object
# Roof Cover                           object
# Rooms                                object
# Square Footage                       object
# Story Height                         object
# Tax District                         object
# Total Appraisal Value                object
# Year Built                           object
# Zone                                 object
# Unnamed: 0                            int64
# Parcel ID                            object
# Land Use                             object
# Property Address                     object
# Suite/ Condo   #                     object
# Property City                        object
# Sale Date                            object
# Sale Price                            int64
# Legal Reference                      object
# Sold As Vacant                       object
# Multiple Parcels Involved in Sale    object
# dtype: object

# %%
jdf.to_csv('jdf.csv')

# %%
mydf=pd.read_csv('jdf.csv')

mydf.head(10)
# Out:
#    Unnamed: 0 Assessment Classification* Assessment Improvement  \
# 0           0                        RES                $86,825
# 1           1                        RES                $46,650
# 2           2                        RES                $19,050
# 3           3                        RES                $49,450
# 4           4                        RES                $36,950
# 5           5                        RES                $36,350
# 6           6                        RES                $85,275
#
#   Assessment Land Assessment Total  Assessment Year  Baths  Beds  \
# 0         $20,000         $106,825             2019      3     4
# 1         $20,000          $66,650             2019      3     3
# 2         $20,800          $39,850             2019      1     3
# 3         $16,250          $65,700             2019      2     3
# 4         $16,250          $53,200             2019      2     4
# 5         $16,250          $52,600             2019      2     3
# 6         $21,475         $106,750             2019      4     5
#
#   Building Condition Building Grade                ...                 \
# 0            Average              C                ...
# 1            Average              C                ...
# 2            Average              C                ...
# 3            Average              C                ...
# 4            Average              C                ...
# 5            Average              C                ...
# 6            Average              C                ...
#
#          Parcel ID       Land Use    Property Address Suite/ Condo   #  \
# 0  007 00 0 138.00  SINGLE FAMILY  1864 FOX CHASE  DR              NaN
# 1  007 00 0 143.00  SINGLE FAMILY  1853  FOX CHASE DR              NaN
# 2  007 10 0 009.00  SINGLE FAMILY     1972 TINNIN  RD              NaN
# 3  007 14 0 024.00  SINGLE FAMILY  1917 GRACELAND  DR              NaN
# 4  007 15 0 008.00  SINGLE FAMILY      1976 SADIE  LN              NaN
# 5  007 15 0 030.00  SINGLE FAMILY  2005 GRACELAND  DR              NaN
# 6  007 15 0 048.00  SINGLE FAMILY  2034  GRACELAND DR              NaN
#
#     Property City   Sale Date Sale Price   Legal Reference Sold As Vacant  \
# 0  GOODLETTSVILLE  2016-09-26     435000  20160927-0101718             No
# 1  GOODLETTSVILLE  2016-01-29     255000  20160129-0008913             No
# 2  GOODLETTSVILLE  2016-12-19     155000  20161220-0133510             No
# 3  GOODLETTSVILLE  2016-09-27     262000  20161005-0105441             No
# 4  GOODLETTSVILLE  2016-07-15     211500  20160720-0074793             No
# 5  GOODLETTSVILLE  2016-12-12     218500  20161214-0131015             No
# 6  GOODLETTSVILLE  2016-04-14     379900  20160418-0036715             No
#
#   Multiple Parcels Involved in Sale
# 0                                No
# 1                                No
# 2                                No
# 3                                No
# 4                                No
# 5                                No
# 6                                No
#
# [7 rows x 47 columns]

# %%
mydf.dtypes
# Out:
# Unnamed: 0                             int64
# Assessment Classification*            object
# Assessment Improvement                object
# Assessment Land                       object
# Assessment Total                      object
# Assessment Year                        int64
# Baths                                  int64
# Beds                                   int64
# Building Condition                    object
# Building Grade                        object
# Building Type                         object
# Current Owner                         object
# Deed Reference                        object
# Exterior Wall                         object
# Fixtures                               int64
# Foundation Type                       object
# Frame Type                            object
# Half Bath                              int64
# Improvement Value                     object
# Land Area                             object
# Land Value                            object
# Location                              object
# Mailing Address                       object
# Map & Parcel                          object
# Most Recent Sale Date                 object
# Most Recent Sale Price                object
# Neighborhood                           int64
# Number of Living Units                 int64
# Roof Cover                            object
# Rooms                                  int64
# Square Footage                        object
# Story Height                          object
# Tax District                          object
# Total Appraisal Value                 object
# Year Built                             int64
# Zone                                   int64
# Unnamed: 0.1                           int64
# Parcel ID                             object
# Land Use                              object
# Property Address                      object
# Suite/ Condo   #                     float64
# Property City                         object
# Sale Date                             object
# Sale Price                             int64
# Legal Reference                       object
# Sold As Vacant                        object
# Multiple Parcels Involved in Sale     object
# dtype: object

# %%
mydf['Land Use'] = mydf['Land Use'].astype(str)

print(type(mydf['Land Use']))

print(mydf['Land Use'].unique())

print(mydf.head())
# Out:
# <class 'pandas.core.series.Series'>
# ['SINGLE FAMILY']
#    Unnamed: 0 Assessment Classification* Assessment Improvement  \
# 0           0                        RES                $86,825
# 1           1                        RES                $46,650
# 2           2                        RES                $19,050
# 3           3                        RES                $49,450
# 4           4                        RES                $36,950
#
#   Assessment Land Assessment Total  Assessment Year  Baths  Beds  \
# 0         $20,000         $106,825             2019      3     4
# 1         $20,000          $66,650             2019      3     3
# 2         $20,800          $39,850             2019      1     3
# 3         $16,250          $65,700             2019      2     3
# 4         $16,250          $53,200             2019      2     4
#
#   Building Condition Building Grade                ...                 \
# 0            Average              C                ...
# 1            Average              C                ...
# 2            Average              C                ...
# 3            Average              C                ...
# 4            Average              C                ...
#
#          Parcel ID       Land Use    Property Address Suite/ Condo   #  \
# 0  007 00 0 138.00  SINGLE FAMILY  1864 FOX CHASE  DR              NaN
# 1  007 00 0 143.00  SINGLE FAMILY  1853  FOX CHASE DR              NaN
# 2  007 10 0 009.00  SINGLE FAMILY     1972 TINNIN  RD              NaN
# 3  007 14 0 024.00  SINGLE FAMILY  1917 GRACELAND  DR              NaN
# 4  007 15 0 008.00  SINGLE FAMILY      1976 SADIE  LN              NaN
#
#     Property City   Sale Date Sale Price   Legal Reference Sold As Vacant  \
# 0  GOODLETTSVILLE  2016-09-26     435000  20160927-0101718             No
# 1  GOODLETTSVILLE  2016-01-29     255000  20160129-0008913             No
# 2  GOODLETTSVILLE  2016-12-19     155000  20161220-0133510             No
# 3  GOODLETTSVILLE  2016-09-27     262000  20161005-0105441             No
# 4  GOODLETTSVILLE  2016-07-15     211500  20160720-0074793             No
#
#   Multiple Parcels Involved in Sale
# 0                                No
# 1                                No
# 2                                No
# 3                                No
# 4                                No
#
# [5 rows x 47 columns]

# %%
mydf.head()
# Out:
#    Unnamed: 0 Assessment Classification* Assessment Improvement  \
# 0           0                        RES                $86,825
# 1           1                        RES                $46,650
# 2           2                        RES                $19,050
# 3           3                        RES                $49,450
# 4           4                        RES                $36,950
#
#   Assessment Land Assessment Total  Assessment Year  Baths  Beds  \
# 0         $20,000         $106,825             2019      3     4
# 1         $20,000          $66,650             2019      3     3
# 2         $20,800          $39,850             2019      1     3
# 3         $16,250          $65,700             2019      2     3
# 4         $16,250          $53,200             2019      2     4
#
#   Building Condition Building Grade                ...                 \
# 0            Average              C                ...
# 1            Average              C                ...
# 2            Average              C                ...
# 3            Average              C                ...
# 4            Average              C                ...
#
#          Parcel ID       Land Use    Property Address Suite/ Condo   #  \
# 0  007 00 0 138.00  SINGLE FAMILY  1864 FOX CHASE  DR              NaN
# 1  007 00 0 143.00  SINGLE FAMILY  1853  FOX CHASE DR              NaN
# 2  007 10 0 009.00  SINGLE FAMILY     1972 TINNIN  RD              NaN
# 3  007 14 0 024.00  SINGLE FAMILY  1917 GRACELAND  DR              NaN
# 4  007 15 0 008.00  SINGLE FAMILY      1976 SADIE  LN              NaN
#
#     Property City   Sale Date Sale Price   Legal Reference Sold As Vacant  \
# 0  GOODLETTSVILLE  2016-09-26     435000  20160927-0101718             No
# 1  GOODLETTSVILLE  2016-01-29     255000  20160129-0008913             No
# 2  GOODLETTSVILLE  2016-12-19     155000  20161220-0133510             No
# 3  GOODLETTSVILLE  2016-09-27     262000  20161005-0105441             No
# 4  GOODLETTSVILLE  2016-07-15     211500  20160720-0074793             No
#
#   Multiple Parcels Involved in Sale
# 0                                No
# 1                                No
# 2                                No
# 3                                No
# 4                                No
#
# [5 rows x 47 columns]
